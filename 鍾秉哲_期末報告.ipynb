# %% [markdown]
# <a href="https://colab.research.google.com/github/a109010114/Computational-Thinking-and-Programming-Design/blob/Computational-Thinking-and-Programming-Design/%E9%8D%BE%E7%A7%89%E5%93%B2_%E6%9C%9F%E6%9C%AB%E5%A0%B1%E5%91%8A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("哈囉!歡迎來到這裡，我是Shu，請問您叫什麼名字?")
name=(input('請輸入您的名字'))
print("您好",name,"有什麼我可以幫你的嗎?")
print("請問今天哪些早餐店有開?")
today=input('今天星期幾?')
if today=="1" or today=="4":
  print('佳蒂和米樂有開')
  print('佳蒂我推薦薯餅蛋捲、巧克力厚片、雞塊都很不錯，更特別的是有黑薏仁漿唷')
  print('米樂我推薦薯餅蛋餅、抹茶厚片、泰式魚排蛋餅和韓式柚子茶都很讚!!')
elif today=="2" or today=="5":
  print('吉的堡和佳蒂有開')
  print('吉的堡的義大利麵和花生醬豬排吐司超級好吃')
  print('佳蒂我推薦薯餅蛋捲、巧克力厚片、雞塊都很不錯，更特別的是有黑薏仁漿唷')
elif today=="3":
  print('吉的堡和米樂有開')
  print('吉的堡的義大利麵和花生醬豬排吐司超級好吃')
  print('米樂我推薦薯餅蛋餅、抹茶厚片、泰式魚排蛋餅和韓式柚子茶都很讚!!')
else:
  print('都沒有營業')
print("那你想要吃哪間呢?")
print('天呀!!聽起來都好好吃，好難決定喔')
print('那我們猜拳決定吧!')
my = int(input('請出拳剪刀[1]、石頭[2]、布[3]'))
print(' 我出拳為', my)
 
import random
computer = random.randint(1,3)
print(' 電腦出拳為', computer)
if my ==1:
  if computer == 1:
     print('平手')
  elif computer == 2:
     print('電腦獲勝')
  else:
     print('玩家獲勝')
elif my==2:
  if computer==1:
    print('玩家獲勝')
  elif computer==2:   
    print('平手')
  else:
    print('電腦獲勝') 
else:
   if computer == 1:
     print('電腦獲勝')
   elif computer == 2:
     print('玩家獲勝')
   else:
     print('平手')
 
win=input('誰贏')
today=input('今天星期幾?')
if today=="1" or today=="2" or today=="4" or today=="5" and win=="你":
 print("吃佳蒂")
 
elif today=="3"and win=="你":
 print("吃吉的堡")
 
elif today=="1" or today=="3" or today=="4"and win=="我":
 print("吃米樂")
 
elif today=="2" or today=="5"and win=="我":
 print("吃吉的堡")
 
else:
 print("沒有營業")
shop=input("請輸入店家")
if shop=="佳蒂":
  hash_brown_omelette=int(input('請輸入薯餅蛋捲數量?'))
  chocolate_toast=int(input('請輸入巧克力厚片數量?'))
  chicken_nuggets=int(input('請輸入雞塊數量?'))
  black_beans=int(input('請輸入黑薏仁漿數量?'))
  total=hash_brown_omelette*30+chocolate_toast*25+chicken_nuggets*30+black_beans*20
  print('訂購總金額為',total) 
elif shop=="吉的堡":
  spaghetti = (int(input('請輸入義大利麵數量?')))
  toast = int(input('請輸入花生醬豬排吐司數量?'))
  total = spaghetti*40 + toast*35
  print('訂購總金額為',total)
elif shop=="米樂":
  hash_brown_omelette=int(input('請輸入薯餅蛋餅數量?'))
  matcha_toast=int(input('請輸入抹茶厚片數量?'))
  thai_fish_fillet=int(input('請輸入泰式魚排蛋餅數量?'))
  korea_pomelo_tea=int(input('請輸入韓式柚子茶數量?'))
  total=hash_brown_omelette*40+matcha_toast*25+thai_fish_fillet*50+korea_pomelo_tea*40
  print('訂購總金額為',total)
else:
  print("今日無營業")
print('如果有任何問題歡迎再詢問我唷!!')

# %%
print("哈囉!歡迎來到這裡，我是Shu，請問您叫什麼名字?")
name=(input('請輸入您的名字'))
print("您好",name,"有什麼我可以幫你的嗎?")
print("請問今天哪些早餐店有開?")
today=input('今天星期幾?')
if today=="1" or today=="4":
  print('佳蒂和米樂有開')
  print('佳蒂我推薦薯餅蛋捲、巧克力厚片、雞塊都很不錯，更特別的是有黑薏仁漿唷')
  print('米樂我推薦薯餅蛋餅、抹茶厚片、泰式魚排蛋餅和韓式柚子茶都很讚!!')
elif today=="2" or today=="5":
  print('吉的堡和佳蒂有開')
  print('吉的堡的義大利麵和花生醬豬排吐司超級好吃')
  print('佳蒂我推薦薯餅蛋捲、巧克力厚片、雞塊都很不錯，更特別的是有黑薏仁漿唷')
elif today=="3":
  print('吉的堡和米樂有開')
  print('吉的堡的義大利麵和花生醬豬排吐司超級好吃')
  print('米樂我推薦薯餅蛋餅、抹茶厚片、泰式魚排蛋餅和韓式柚子茶都很讚!!')
else:
  print('都沒有營業')
print("那你想要吃哪間呢?")
print('天呀!!聽起來都好好吃，好難決定喔')
print('那我們猜拳決定吧!')
my = int(input('請出拳剪刀[1]、石頭[2]、布[3]'))
print(' 我出拳為', my)
 
import random
computer = random.randint(1,3)
print(' 電腦出拳為', computer)
if my ==1:
  if computer == 1:
     print('平手')
  elif computer == 2:
     print('電腦獲勝')
  else:
     print('玩家獲勝')
elif my==2:
  if computer==1:
    print('玩家獲勝')
  elif computer==2:   
    print('平手')
  else:
    print('電腦獲勝') 
else:
   if computer == 1:
     print('電腦獲勝')
   elif computer == 2:
     print('玩家獲勝')
   else:
     print('平手')
 
win=input('誰贏')
today=input('今天星期幾?')
if today=="1" or today=="2" or today=="4" or today=="5" and win=="你":
 print("吃佳蒂")
 
elif today=="3"and win=="你":
 print("吃吉的堡")
 
elif today=="1" or today=="3" or today=="4"and win=="我":
 print("吃米樂")
 
elif today=="2" or today=="5"and win=="我":
 print("吃吉的堡")
 
else:
 print("沒有營業")
shop=input("請輸入店家")
if shop=="佳蒂":
  hash_brown_omelette=int(input('請輸入薯餅蛋捲數量?'))
  chocolate_toast=int(input('請輸入巧克力厚片數量?'))
  chicken_nuggets=int(input('請輸入雞塊數量?'))
  black_beans=int(input('請輸入黑薏仁漿數量?'))
  total=hash_brown_omelette*30+chocolate_toast*25+chicken_nuggets*30+black_beans*20
  print('訂購總金額為',total) 
elif shop=="吉的堡":
  spaghetti = (int(input('請輸入義大利麵數量?')))
  toast = int(input('請輸入花生醬豬排吐司數量?'))
  total = spaghetti*40 + toast*35
  print('訂購總金額為',total)
elif shop=="米樂":
  hash_brown_omelette=int(input('請輸入薯餅蛋餅數量?'))
  matcha_toast=int(input('請輸入抹茶厚片數量?'))
  thai_fish_fillet=int(input('請輸入泰式魚排蛋餅數量?'))
  korea_pomelo_tea=int(input('請輸入韓式柚子茶數量?'))
  total=hash_brown_omelette*40+matcha_toast*25+thai_fish_fillet*50+korea_pomelo_tea*40
  print('訂購總金額為',total)
else:
  print("今日無營業")
print('如果有任何問題歡迎再詢問我唷!!')
# Out:
# 哈囉!歡迎來到這裡，我是Shu，請問您叫什麼名字?
# 請輸入您的名字An
# 您好 An 有什麼我可以幫你的嗎?
# 請問今天哪些早餐店有開?
# 今天星期幾?1
# 佳蒂和米樂有開
# 佳蒂我推薦薯餅蛋捲、巧克力厚片、雞塊都很不錯，更特別的是有黑薏仁漿唷
# 米樂我推薦薯餅蛋餅、抹茶厚片、泰式魚排蛋餅和韓式柚子茶都很讚!!
# 那你想要吃哪間呢?
# 天呀!!聽起來都好好吃，好難決定喔
# 那我們猜拳決定吧!
# 請出拳剪刀[1]、石頭[2]、布[3]2
#  我出拳為 2
#  電腦出拳為 2
# 平手
# 誰贏2
# 今天星期幾?1
# 吃佳蒂
# 請輸入店家佳蒂
# 請輸入薯餅蛋捲數量?2
# 請輸入巧克力厚片數量?3
# 請輸入雞塊數量?4
# 請輸入黑薏仁漿數量?5
# 訂購總金額為 355
# 如果有任何問題歡迎再詢問我唷!!

# %% [markdown]
# ######Robot:哈囉!歡迎來到這裡，我是Shu，請問您叫什麼名字?
# #####Robot:您好,name,有什麼我可以幫你的嗎?
# #####Student:請問今天哪些早餐店有開?
# #####Robot:今天星期幾?
# #####Student:今天星期X
# #####星期一:佳蒂、米樂
# #####星期二:吉的堡、佳蒂
# #####星期三:吉的堡、米樂
# #####星期四:佳蒂、米樂
# #####星期五:吉的堡、佳蒂
# #####星期六、日:沒有營業
# #####(說明營業後print菜單推薦)
# #####佳蒂推薦:薯餅蛋捲、巧克力厚片、雞塊、黑薏仁漿
# #####米樂推薦:薯餅蛋餅、抹茶厚片、泰式魚排蛋餅、韓式柚子茶
# #####吉的堡推薦:義大利麵、花生醬豬排吐司
# #####Robot:那你想要吃哪間呢?
# #####Student:天呀!!聽起來都好好吃，好難決定喔
# #####Robot:那我們猜拳決定吧!
# #####執行猜拳遊戲
# #####如果今天
# #####星期一/Robot贏:吃佳蒂 Student贏:吃米樂
# #####星期二/Robot贏:吃佳蒂 Student贏:吃吉的堡
# #####星期三/Robot贏:吃吉的堡 Student贏:吃米樂
# #####星期四/Robot贏:吃佳蒂 Student贏:吃米樂
# #####星期五/Robot贏:吃佳蒂 Student贏:吃吉的堡
# #####Student輸入店家、星期並點菜
# #####佳蒂:薯餅蛋捲$30、巧克力厚片$25、雞塊$30、黑薏仁漿$20
# #####米樂:薯餅蛋餅$40、抹茶厚片$25、泰式魚排蛋餅$50、韓式柚子茶$40
# #####吉的堡:義大利麵$40、花生醬豬排吐司$35
# #####點餐完畢後輸入數量計算總金額
# #####Robot:如果有任何問題歡迎再詢問我唷!!

# %% [markdown]
# ##組長：陳安婷 A109010021
# ##組員：方嘉琳 A109010171
# ##組員：張佳倪 A109010024
# ##組員：鍾秉哲 A109010114
